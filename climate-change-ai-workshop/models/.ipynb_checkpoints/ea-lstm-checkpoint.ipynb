# %%
import os
import math
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import OrderedDict

from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

from tensorflow.keras import Input
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import concatenate, Permute, Dense, Dropout, LSTM
from keras.constraints import maxnorm, nonneg

from attention import Attention

# %%
# def window_mean(arr, num_steps, axis=1):
#     assert num_steps < arr.shape[axis], f'num_steps ({num_steps}) must be a smaller than the length of the specified axis ({arr.shape[axis]})'
#     assert arr.shape[axis] % num_steps == 0, f'num_steps must be a factor of the length of the specified axis ({arr.shape[axis]})'
#     assert isinstance(num_steps, int), 'num_steps must be an integer'
#     return np.array(np.split(arr, num_steps, axis=axis)).mean(axis=0).astype(np.float32)

# def pull_apart(arr, idx, axis=1):
#     return np.split(arr, np.cumsum(idx)[:-1], axis=axis)

# daily_data = np.load('../data/dailyt30_features.npy', allow_pickle=True)
# monthly_data = np.load('../data/monthly_features.npy', allow_pickle=True)
# daily_target = np.load('../data/dailyt30_target.npy', allow_pickle=True)
# monthly_target = np.load('../data/monthly_target.npy', allow_pickle=True)

# data_scales = OrderedDict(
#     ('1d', {'data': daily_data, 'target': daily_target}),
#     ('3d', {'data': window_mean(daily_data, 3), 'target': daily_target}),
#     ('10d', {'data': window_mean(daily_data, 10), 'target': daily_target}),
#     ('15d', {'data': window_mean(daily_data, 15), 'target': daily_target}),
#     ('30d', {'data': monthly_data, 'target': monthly_target}),
# )

# #Concatenate datasets and save lengths to pull them apart later
# data = [data['data'] for scale, data in data_scales.items()]
# scale_idx = [d.shape[1] for d in data]
# data = np.concatenate(data, axis=1)

# #Adding a lag to monthly targets
# lag = 1
# data = data[:-lag,:,:]
# monthly_target = monthly_target[lag:]

# %%
def window_mean(arr, num_steps, axis=1):
    assert num_steps < arr.shape[axis], f'num_steps ({num_steps}) must be a smaller than the length of the specified axis ({arr.shape[axis]})'
    assert arr.shape[axis] % num_steps == 0, f'num_steps must be a factor of the length of the specified axis ({arr.shape[axis]})'
    assert isinstance(num_steps, int), 'num_steps must be an integer'
    return np.array(np.split(arr, num_steps, axis=axis)).mean(axis=0).astype(np.float32)

def pull_apart(arr, idx, axis=1):
    return np.split(arr, np.cumsum(idx)[:-1], axis=axis)

daily_data = np.load('../data/dailyt30_features.npy', allow_pickle=True)
monthly_data = np.load('../data/monthly_features.npy', allow_pickle=True)
daily_target = np.load('../data/dailyt30_target.npy', allow_pickle=True)
monthly_target = np.load('../data/monthly_target.npy', allow_pickle=True)

# Note that these must be factors of 30...
data = [
    daily_data,  # 1day
    window_mean(daily_data, 3),  # 3day
    window_mean(daily_data, 10),  # 10day
    window_mean(daily_data, 15),  # 15day
    monthly_data,  # 1mo (30day)
]

#Concatenate datasets and save lengths to pull them apart later
scale_idx = [d.shape[1] for d in data]
data = np.concatenate(data, axis=1)

#Adding a lag to monthly targets
lag = 1
data = data[:-lag,:,:]
monthly_target = monthly_target[lag:]

# %%
# Sequential split train:val data in 80:20 sequentially 
test_years = 7

LEN_DATA = len(data) #total number of pixels
NUM_TRAIN = LEN_DATA - (12*test_years) #reserve last 20 years for testing 
NUM_VALID = LEN_DATA - NUM_TRAIN

print(f'{LEN_DATA=}', f'i.e. {LEN_DATA / 12:.1f} years')
print(f'{NUM_TRAIN=}', f'i.e. {NUM_TRAIN / 12:.1f} years')
print(f'{NUM_VALID=}', f'i.e. {NUM_VALID / 12:.1f} years')

x_train = data[:NUM_TRAIN]
x_valid = data[NUM_TRAIN:]

#split features and labels
y_train = monthly_target[:NUM_TRAIN] #target is last column i-e sea-ice
y_valid = monthly_target[NUM_TRAIN:] #target is last column i-e sea-ice
# Out:
# LEN_DATA=479 i.e. 39.9 years
# NUM_TRAIN=395 i.e. 32.9 years
# NUM_VALID=84 i.e. 7.0 years

# %%
def reshape_features(dataset, timesteps=1):
    X = dataset.reshape((int(dataset.shape[0]/timesteps)), timesteps, dataset.shape[1])
    print(f'Converted from shape {dataset.shape} to shape {X.shape}')
    return X

timesteps = x_train.shape[1]

# Normalize the features, requires reshaping to 2D (?)
scaler_f = StandardScaler()
x_train = scaler_f.fit_transform(x_train.reshape(-1,x_train.shape[2]))
x_valid = scaler_f.transform(x_valid.reshape(-1,x_valid.shape[2]))

scaler_l = StandardScaler()
y_train = scaler_l.fit_transform(y_train.reshape(-1,1))
y_valid = scaler_l.transform(y_valid.reshape(-1,1))

# Revert it back tp 3D
x_train = reshape_features(x_train, timesteps)
x_valid = reshape_features(x_valid, timesteps)

print(f'{x_train.shape=}')
print(f'{y_train.shape=}')
print(f'{x_valid.shape=}')
print(f'{y_valid.shape=}')
# Out:
# Converted from shape (18170, 11) to shape (395, 46, 11)
# Converted from shape (3864, 11) to shape (84, 46, 11)
# x_train.shape=(395, 46, 11)
# y_train.shape=(395, 1)
# x_valid.shape=(84, 46, 11)
# y_valid.shape=(84, 1)

# %%
num_features = 11

models = []
models_inputs = []
for num_days in scale_idx:
    model_input= Input(shape=(num_days, num_features)) #replace (1,10) with (1,11) for 11 features
    
    model = Permute((2,1), input_shape=(num_days, num_features))(model_input)
    model = LSTM(64, return_sequences=True)(model)
    model = Dropout(0.2)(model)
    model = LSTM(32, return_sequences=True)(model)
    model = Attention()(model)
    model = Dense(1)(model)
    
    models_inputs.append(model_input)
    models.append(model)

ensemble = concatenate(models)
merged_model = Dense(1)(ensemble)
model = Model(inputs=models_inputs, outputs=merged_model, name='EALSTM')
model.summary()
# Out:
# Model: "EALSTM"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 30, 11)]     0           []
#
#  input_2 (InputLayer)           [(None, 10, 11)]     0           []
#
#  input_3 (InputLayer)           [(None, 3, 11)]      0           []
#
#  input_4 (InputLayer)           [(None, 2, 11)]      0           []
#
#  input_5 (InputLayer)           [(None, 1, 11)]      0           []
#
#  permute (Permute)              (None, 11, 30)       0           ['input_1[0][0]']
#
#  permute_1 (Permute)            (None, 11, 10)       0           ['input_2[0][0]']
#
#  permute_2 (Permute)            (None, 11, 3)        0           ['input_3[0][0]']
#
#  permute_3 (Permute)            (None, 11, 2)        0           ['input_4[0][0]']
#
#  permute_4 (Permute)            (None, 11, 1)        0           ['input_5[0][0]']
#
#  lstm (LSTM)                    (None, 11, 64)       24320       ['permute[0][0]']
#
#  lstm_2 (LSTM)                  (None, 11, 64)       19200       ['permute_1[0][0]']
#
#  lstm_4 (LSTM)                  (None, 11, 64)       17408       ['permute_2[0][0]']
#
#  lstm_6 (LSTM)                  (None, 11, 64)       17152       ['permute_3[0][0]']
#
#  lstm_8 (LSTM)                  (None, 11, 64)       16896       ['permute_4[0][0]']
#
#  dropout (Dropout)              (None, 11, 64)       0           ['lstm[0][0]']
#
#  dropout_1 (Dropout)            (None, 11, 64)       0           ['lstm_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 11, 64)       0           ['lstm_4[0][0]']
#
#  dropout_3 (Dropout)            (None, 11, 64)       0           ['lstm_6[0][0]']
#
#  dropout_4 (Dropout)            (None, 11, 64)       0           ['lstm_8[0][0]']
#
#  lstm_1 (LSTM)                  (None, 11, 32)       12416       ['dropout[0][0]']
#
#  lstm_3 (LSTM)                  (None, 11, 32)       12416       ['dropout_1[0][0]']
#
#  lstm_5 (LSTM)                  (None, 11, 32)       12416       ['dropout_2[0][0]']
#
#  lstm_7 (LSTM)                  (None, 11, 32)       12416       ['dropout_3[0][0]']
#
#  lstm_9 (LSTM)                  (None, 11, 32)       12416       ['dropout_4[0][0]']
#
#  attention (Attention)          (None, 128)          9216        ['lstm_1[0][0]']
#
#  attention_1 (Attention)        (None, 128)          9216        ['lstm_3[0][0]']
#
#  attention_2 (Attention)        (None, 128)          9216        ['lstm_5[0][0]']
#
#  attention_3 (Attention)        (None, 128)          9216        ['lstm_7[0][0]']
#
#  attention_4 (Attention)        (None, 128)          9216        ['lstm_9[0][0]']
#
#  dense (Dense)                  (None, 1)            129         ['attention[0][0]']
#
#  dense_1 (Dense)                (None, 1)            129         ['attention_1[0][0]']
#
#  dense_2 (Dense)                (None, 1)            129         ['attention_2[0][0]']
#
#  dense_3 (Dense)                (None, 1)            129         ['attention_3[0][0]']
#
#  dense_4 (Dense)                (None, 1)            129         ['attention_4[0][0]']
#
#  concatenate (Concatenate)      (None, 5)            0           ['dense[0][0]',
#                                                                   'dense_1[0][0]',
#                                                                   'dense_2[0][0]',
#                                                                   'dense_3[0][0]',
#                                                                   'dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 1)            6           ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 203,787
# Trainable params: 203,787
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#Compiling the network
model.compile(loss='mean_squared_error', optimizer='adam')
checkpoint_path='./testmodel.h5'
keras_callbacks   = [
      EarlyStopping(monitor='val_loss', patience=60, mode='min', min_delta=0.001),
      ModelCheckpoint(checkpoint_path, monitor='val_loss', save_best_only=True, mode='min')
]

# %%
x_train_sets = pull_apart(x_train, scale_idx, axis=1)
x_train_sets = [d.astype('float32') for d in x_train_sets]

x_valid_sets = pull_apart(x_valid, scale_idx, axis=1)
x_valid_sets = [d.astype('float32') for d in x_valid_sets]

history=model.fit(
    x_train_sets,
    y_train,
    epochs=500,
    batch_size=64,
    verbose=0,
    validation_split=0.3,
    shuffle=True,
    callbacks=keras_callbacks)

plt.figure(figsize=(10, 3))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()
# Out:
# 2022-02-19 11:47:33.716185: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-02-19 11:47:38.099413: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" model: "0" num_cores: 8 environment { key: "cpu_instruction_set" value: "ARM NEON" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 16384 l2_cache_size: 524288 l3_cache_size: 524288 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2022-02-19 11:47:38.099538: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" model: "0" num_cores: 8 environment { key: "cpu_instruction_set" value: "ARM NEON" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 16384 l2_cache_size: 524288 l3_cache_size: 524288 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2022-02-19 11:47:38.099597: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" model: "0" num_cores: 8 environment { key: "cpu_instruction_set" value: "ARM NEON" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 16384 l2_cache_size: 524288 l3_cache_size: 524288 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2022-02-19 11:47:38.099633: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" model: "0" num_cores: 8 environment { key: "cpu_instruction_set" value: "ARM NEON" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 16384 l2_cache_size: 524288 l3_cache_size: 524288 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2022-02-19 11:47:38.100040: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" model: "0" num_cores: 8 environment { key: "cpu_instruction_set" value: "ARM NEON" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 16384 l2_cache_size: 524288 l3_cache_size: 524288 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2022-02-19 11:47:40.416754: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" model: "0" num_cores: 8 environment { key: "cpu_instruction_set" value: "ARM NEON" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 16384 l2_cache_size: 524288 l3_cache_size: 524288 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2022-02-19 11:47:40.417332: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" model: "0" num_cores: 8 environment { key: "cpu_instruction_set" value: "ARM NEON" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 16384 l2_cache_size: 524288 l3_cache_size: 524288 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2022-02-19 11:47:40.417535: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" model: "0" num_cores: 8 environment { key: "cpu_instruction_set" value: "ARM NEON" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 16384 l2_cache_size: 524288 l3_cache_size: 524288 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2022-02-19 11:47:40.417843: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" model: "0" num_cores: 8 environment { key: "cpu_instruction_set" value: "ARM NEON" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 16384 l2_cache_size: 524288 l3_cache_size: 524288 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2022-02-19 11:47:40.417881: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" model: "0" num_cores: 8 environment { key: "cpu_instruction_set" value: "ARM NEON" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 16384 l2_cache_size: 524288 l3_cache_size: 524288 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }

# %%
# Predict
train_pred = model.predict(x_train_sets)
valid_pred = model.predict(x_valid_sets)

# Inverse the transforms
train_pred_inv = scaler_l.inverse_transform(train_pred)
valid_pred_inv = scaler_l.inverse_transform(valid_pred)
y_valid_inv = scaler_l.inverse_transform(y_valid)
# Out:
# 2022-02-19 11:47:57.201032: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" model: "0" num_cores: 8 environment { key: "cpu_instruction_set" value: "ARM NEON" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 16384 l2_cache_size: 524288 l3_cache_size: 524288 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2022-02-19 11:47:57.201247: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" model: "0" num_cores: 8 environment { key: "cpu_instruction_set" value: "ARM NEON" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 16384 l2_cache_size: 524288 l3_cache_size: 524288 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2022-02-19 11:47:57.201425: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" model: "0" num_cores: 8 environment { key: "cpu_instruction_set" value: "ARM NEON" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 16384 l2_cache_size: 524288 l3_cache_size: 524288 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2022-02-19 11:47:57.201684: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" model: "0" num_cores: 8 environment { key: "cpu_instruction_set" value: "ARM NEON" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 16384 l2_cache_size: 524288 l3_cache_size: 524288 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }
# 2022-02-19 11:47:57.201720: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:689] Error in PredictCost() for the op: op: "Softmax" attr { key: "T" value { type: DT_FLOAT } } inputs { dtype: DT_FLOAT shape { unknown_rank: true } } device { type: "CPU" model: "0" num_cores: 8 environment { key: "cpu_instruction_set" value: "ARM NEON" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 16384 l2_cache_size: 524288 l3_cache_size: 524288 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { unknown_rank: true } }

# %%
# RMSE
rmse = math.sqrt(mean_squared_error(y_valid_inv, valid_pred_inv))

# NRMSE
y_max = y_valid.max()
y_min = y_valid.min()
nrmse = rmse /(y_valid_inv.mean()) 

# R2
r_sq = r2_score(y_valid_inv, valid_pred_inv)

print(f'Test RMSE: {rmse}.3f')
print(f'Test NRMSE: {nrmse}.5f')
print(f'Test R_Square: {r_sq}.3f')

fig, axs = plt.subplots(1, 2, figsize=(10, 4))
axs[0].scatter(y_train, train_pred, c='grey')
axs[0].plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--', lw=2)
axs[0].set_xlabel('Observed')
axs[0].set_ylabel('Predicted')
axs[0].set_title('Training set')

axs[1].scatter(y_valid, valid_pred, c='grey')
axs[1].plot([y_valid.min(), y_valid.max()], [y_valid.min(), y_valid.max()], 'k--', lw=2)
axs[1].set_xlabel('Observed')
axs[1].set_ylabel('Predicted')
axs[1].set_title('Test set')

plt.show()
# Out:
# Test RMSE: 774952.7037904839.3f
# Test NRMSE: 0.07196463722523933.5f
# Test R_Square: 0.9473121521516581.3f

# %%
x_range = np.arange(len(valid_pred))

fig, ax = plt.subplots(figsize=(20, 4))
ax.bar(x_range + 0.00, y_valid_inv.flatten(), color='grey', width=0.5, label='Observed')
ax.bar(x_range + 0.5, valid_pred_inv.flatten(), color='C1', width=0.5, label='Predicted')
plt.legend()
plt.show()

fig, ax = plt.subplots(figsize=(20, 4))
ax.plot(y_valid_inv, label='Observed', color='grey')
ax.plot(valid_pred_inv, label='Predicted', color='C1')
plt.legend()
plt.show()

# %%
model.layers[-1].weights
# model.layers[-1].bias
# Out:
# [<tf.Variable 'dense_5/kernel:0' shape=(5, 1) dtype=float32, numpy=
#  array([[-0.07454764],
#         [-0.91864353],
#         [ 0.663297  ],
#         [ 0.77133065],
#         [-0.38396373]], dtype=float32)>,
#  <tf.Variable 'dense_5/bias:0' shape=(1,) dtype=float32, numpy=array([0.00362096], dtype=float32)>]
